# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
csvpath = Path('../PyBank/Resources/budget_data.csv')

# Initialize dictionary of records
budget_records = {}

# Open the csv file as an object
with open(csvpath, 'r') as csvfile:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')

    # Read the header row first (skip this step if there is no header)
    csv_header = next(csvreader)
    # Print the header
    print(csv_header)
    
    total_pnl = 0
    total_month = 0
 
    # Read each row of data after the header
    for row in csvreader:
        # Print the row
        print(row)

        # Set the 'date_budget', 'count', and 'pnl' variables for better
        # readability, convert strings to ints for numerical calculations
        date_budget = row[0]
        # The total number of months included in the dataset.
        pnl = int(row[1])
        total_month += 1
        
        print(f"this is count:", pnl)
    
        #The total number of months included in the dataset.
        total_pnl = total_pnl + pnl
        
        # Calculate the average and round to the nearest 2 decimal places
        #average = round(pnl / count, 2)
        # Append the average to the row
        #row.append(average)
        # Append the row to the list of records
        #budget_records.append(row)
print (f"total month", total_month)
print (f"total pnl: ", total_pnl)
# Out:
# ['Date', 'Profit/Losses']
# ['Jan-2010', '867884']
# this is count: 867884
# ['Feb-2010', '984655']
# this is count: 984655
# ['Mar-2010', '322013']
# this is count: 322013
# ['Apr-2010', '-69417']
# this is count: -69417
# ['May-2010', '310503']
# this is count: 310503
# ['Jun-2010', '522857']
# this is count: 522857
# ['Jul-2010', '1033096']
# this is count: 1033096
# ['Aug-2010', '604885']
# this is count: 604885
# ['Sep-2010', '-216386']
# this is count: -216386
# ['Oct-2010', '477532']
# this is count: 477532
# ['Nov-2010', '893810']
# this is count: 893810
# ['Dec-2010', '-80353']
# this is count: -80353
# ['Jan-2011', '779806']
# this is count: 779806
# ['Feb-2011', '-335203']
# this is count: -335203
# ['Mar-2011', '697845']
# this is count: 697845
# ['Apr-2011', '793163']
# this is count: 793163
# ['May-2011', '485070']
# this is count: 485070
# ['Jun-2011', '584122']
# this is count: 584122
# ['Jul-2011', '62729']
# this is count: 62729
# ['Aug-2011', '668179']
# this is count: 668179
# ['Sep-2011', '899906']
# this is count: 899906
# ['Oct-2011', '834719']
# this is count: 834719
# ['Nov-2011', '132003']
# this is count: 132003
# ['Dec-2011', '309978']
# this is count: 309978
# ['Jan-2012', '-755566']
# this is count: -755566
# ['Feb-2012', '1170593']
# this is count: 1170593
# ['Mar-2012', '252788']
# this is count: 252788
# ['Apr-2012', '1151518']
# this is count: 1151518
# ['May-2012', '817256']
# this is count: 817256
# ['Jun-2012', '570757']
# this is count: 570757
# ['Jul-2012', '506702']
# this is count: 506702
# ['Aug-2012', '-1022534']
# this is count: -1022534
# ['Sep-2012', '475062']
# this is count: 475062
# ['Oct-2012', '779976']
# this is count: 779976
# ['Nov-2012', '144175']
# this is count: 144175
# ['Dec-2012', '542494']
# this is count: 542494
# ['Jan-2013', '359333']
# this is count: 359333
# ['Feb-2013', '321469']
# this is count: 321469
# ['Mar-2013', '67780']
# this is count: 67780
# ['Apr-2013', '471435']
# this is count: 471435
# ['May-2013', '565603']
# this is count: 565603
# ['Jun-2013', '872480']
# this is count: 872480
# ['Jul-2013', '789480']
# this is count: 789480
# ['Aug-2013', '999942']
# this is count: 999942
# ['Sep-2013', '-1196225']
# this is count: -1196225
# ['Oct-2013', '268997']
# this is count: 268997
# ['Nov-2013', '-687986']
# this is count: -687986
# ['Dec-2013', '1150461']
# this is count: 1150461
# ['Jan-2014', '682458']
# this is count: 682458
# ['Feb-2014', '617856']
# this is count: 617856
# ['Mar-2014', '824098']
# this is count: 824098
# ['Apr-2014', '581943']
# this is count: 581943
# ['May-2014', '132864']
# this is count: 132864
# ['Jun-2014', '448062']
# this is count: 448062
# ['Jul-2014', '689161']
# this is count: 689161
# ['Aug-2014', '800701']
# this is count: 800701
# ['Sep-2014', '1166643']
# this is count: 1166643
# ['Oct-2014', '947333']
# this is count: 947333
# ['Nov-2014', '578668']
# this is count: 578668
# ['Dec-2014', '988505']
# this is count: 988505
# ['Jan-2015', '1139715']
# this is count: 1139715
# ['Feb-2015', '1029471']
# this is count: 1029471
# ['Mar-2015', '687533']
# this is count: 687533
# ['Apr-2015', '-524626']
# this is count: -524626
# ['May-2015', '158620']
# this is count: 158620
# ['Jun-2015', '87795']
# this is count: 87795
# ['Jul-2015', '423389']
# this is count: 423389
# ['Aug-2015', '840723']
# this is count: 840723
# ['Sep-2015', '568529']
# this is count: 568529
# ['Oct-2015', '332067']
# this is count: 332067
# ['Nov-2015', '989499']
# this is count: 989499
# ['Dec-2015', '778237']
# this is count: 778237
# ['Jan-2016', '650000']
# this is count: 650000
# ['Feb-2016', '-1100387']
# this is count: -1100387
# ['Mar-2016', '-174946']
# this is count: -174946
# ['Apr-2016', '757143']
# this is count: 757143
# ['May-2016', '445709']
# this is count: 445709
# ['Jun-2016', '712961']
# this is count: 712961
# ['Jul-2016', '-1163797']
# this is count: -1163797
# ['Aug-2016', '569899']
# this is count: 569899
# ['Sep-2016', '768450']
# this is count: 768450
# ['Oct-2016', '102685']
# this is count: 102685
# ['Nov-2016', '795914']
# this is count: 795914
# ['Dec-2016', '60988']
# this is count: 60988
# ['Jan-2017', '138230']
# this is count: 138230
# ['Feb-2017', '671099']
# this is count: 671099
# total month 86
# total pnl:  38382578

# %%
# Set the path for the output.csv
output = Path("../PyBank/output.csv")
# Open the output path as a file and pass into the 'csv.writer()' function
# Set the delimiter/separater as a ','
with open(output, 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')

    # Loop through the list of records and write every record to the
    # output csv file
    for record in budget_records:
        csvwriter.writerow(record)
