# %%
# Import the pathlib and csv library
from contextlib import nullcontext
from pathlib import Path
import csv

# Set the file path
csvpath = Path('../PyBank/Resources/budget_data.csv')

# Initialize dictionary of records
budget_records = {}

#Initialize list
great_prof = []
great_loss = []


#define variables
total_pnl = 0
total_month = 0
total_change = 0
priordate = ""


# Open the csv file as an object
with open(csvpath, 'r') as csvfile:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')

    # Read the header row first (skip this step if there is no header)
    csv_header = next(csvreader)
    # Print the header
    print(csv_header)
    
    
    # Read each row of data after the header
    for row in csvreader:
        # Print the row
        #print(row)

        # Set the 'date_budget', 'count', and 'pnl' variables for better
        # readability, convert strings to ints for numerical calculations
        date_budget = row[0]
        pnl = int(row[1])
        
        # The total number of months included in the dataset.
        total_month += 1       
    
        #The total number of months included in the dataset.
        total_pnl = total_pnl + pnl
        
        # Calculate the total change and round to the nearest 2 decimal places
        # Find the Greatest Increase and Decrease in profit 
        if priordate not in budget_records.keys():
            budget_records[date_budget]= pnl
            priordate = date_budget
            great_prof = [date_budget, pnl]
            great_loss = [date_budget, pnl]
      
        elif priordate in budget_records.keys():
            total_change = (pnl - budget_records.get(priordate)) + total_change
            total_change = round(total_change,2)
            budget_records[date_budget] =pnl
            priordate = date_budget

            #Find the Greatest Increase and Decrease in Profit
            if great_prof[1]<pnl:
                great_prof = [date_budget, pnl]
            elif great_loss[1] > pnl:
                great_loss = [date_budget, pnl]
       
# calculate average change
total_change = total_change/(total_month-1)
total_change = round(total_change,2)
       
print (f"Total Months", total_month)
print (f"Total: $", total_pnl)
print (f"Total Change: $", total_change)
print (f"Greatest Increase in Profits:", great_prof[0], "$", great_prof[1])
print (f"Greatest Decrease in Profits:", great_loss[0], "$", great_loss[1])
# Out:
# ['Date', 'Profit/Losses']
# Total Months 86
# Total: $ 38382578
# Total Change: $ -2315.12
# Greatest Increase in Profits: Feb-2012 $ 1170593
# Greatest Decrease in Profits: Sep-2013 $ -1196225

# %%
# Set the path for the output.csv
output = Path("../PyBank/output.csv")
# Open the output path as a file and pass into the 'csv.writer()' function
# Set the delimiter/separater as a ','
with open(output, 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')

    # Loop through the list of records and write every record to the
    # output csv file
    for record in budget_records:
        csvwriter.writerow(record)
